# %% [markdown]
# # Exercise 2: Title of the Notebook
# # Data Science Tools and Ecosystem

# %% [markdown]
# # Exercise 3: Introduction
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# # Exercise 10: Objectives
# **Objectives:**
# - List popular languages for Data Science
# - List commonly used libraries in Data Science
# - Create tables using Markdown
# - Perform arithmetic operations in Python
# - Convert minutes to hours

# %% [markdown]
# # Exercise 4: Data Science Languages
# Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. R
# 3. SQL

# %% [markdown]
# # Exercise 5: Data Science Libraries
# Some of the commonly used libraries used by Data Scientists include:
# 1. Pandas
# 2. NumPy
# 3. Matplotlib

# %% [markdown]
# # Exercise 6: Table of Data Science Tools
# | Data Science Tools |
# |--------------------|
# | Jupyter Notebook   |
# | RStudio            |
# | Apache Zeppelin    |

# %% [markdown]
# # Exercise 7: Arithmetic Expression Examples
# ### Below are a few examples of evaluating arithmetic expressions in Python.

# %%
# Exercise 8: Multiply and Add Numbers
# This a simple arithmetic expression to multiply then add integers
(3*4)+5

# %%
# Exercise 9: Convert Minutes to Hours
# This will convert 200 minutes to hours by dividing by 60
200/60

# %% [markdown]
# # Exercise 11: Author
# ## Author
# Amit Rath

# %% [markdown]
# # Exercise 12: GitHub Sharing
# Upload this notebook to a public GitHub repository as instructed.

# %% [markdown]
# # Exercise 13: Screenshot
# Take a screenshot of the first page of this notebook.
